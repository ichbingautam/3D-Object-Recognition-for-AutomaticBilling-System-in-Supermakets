# %%
import numpy
import cv2
import matplotlib.pyplot as plt

# %%
image_path = 'D:/Project/FinalYearProjects/Model-Training/dataset/Annotations/image1.png'
image = cv2.imread(image_path)
plt.imshow(image)
plt.show()

# %%
image_gray = cv2.imread(image_path,0)
print("PIXEL VALUES:\n", "cinthol soap", image_gray[250, 300])
# Out:
# PIXEL VALUES:
#  cinthol soap 26

# %%
image_path = 'D:/Project/FinalYearProjects/Model-Training/dataset/Annotations/image11.png'
image = cv2.imread(image_path)
plt.imshow(image)
plt.show()

# %%
image_gray = cv2.imread(image_path,0)
print("PIXEL VALUES:\n", "coconut oil", image_gray[150, 300])
# Out:
# PIXEL VALUES:
#  coconut oil 45

# %%
image_path = 'D:/Project/FinalYearProjects/Model-Training/dataset/Annotations/image18.png'
image = cv2.imread(image_path)
plt.imshow(image)
plt.show()

# %%
image_gray = cv2.imread(image_path,0)
print("PIXEL VALUES:\n", "colgate salt large", image_gray[250, 200])
# Out:
# PIXEL VALUES:
#  colgate salt large 114

# %%
image_path = 'D:/Project/FinalYearProjects/Model-Training/dataset/Annotations/image25.png'
image = cv2.imread(image_path)
plt.imshow(image)
plt.show()

# %%
image_gray = cv2.imread(image_path,0)
print("PIXEL VALUES:\n", "ghadi soap", image_gray[150, 300])
# Out:
# PIXEL VALUES:
#  ghadi soap 33

# %%
image_path = 'D:/Project/FinalYearProjects/Model-Training/dataset/Annotations/image38.png'
image = cv2.imread(image_path)
plt.imshow(image)
plt.show()

# %%
image_gray = cv2.imread(image_path,0)
print("PIXEL VALUES:\n", "lemon facewash", image_gray[200, 200])
# Out:
# PIXEL VALUES:
#  lemon facewash 84

# %%
image_path = 'D:/Project/FinalYearProjects/Model-Training/dataset/Annotations/image44.png'
image = cv2.imread(image_path)
plt.imshow(image)
plt.show()

# %%
image_gray = cv2.imread(image_path,0)
print("PIXEL VALUES:\n", "neutrogena moisturizer", image_gray[250, 100])
# Out:
# PIXEL VALUES:
#  neutrogena moisturizer 58

# %%
image_path = 'D:/Project/FinalYearProjects/Model-Training/dataset/Annotations/image55.png'
image = cv2.imread(image_path)
plt.imshow(image)
plt.show()

# %%
image_gray = cv2.imread(image_path,0)
print("PIXEL VALUES:\n", "colagte salt small", image_gray[170, 300])
# Out:
# PIXEL VALUES:
#  colagte salt small 76
